# %%
# !pip install qiskit pylatexenc

# %%
from qiskit import QuantumCircuit

# %%
import numpy as np
import random
a = np.sqrt(random.uniform(0, 1))
b = np.sqrt(1 - a**2)

qc = QuantumCircuit(3)
qc.initialize([a, b], 0, 0)
qc.barrier()
qc.x(1)
qc.x(2)
qc.barrier()
qc.h(2)
qc.cx(2, 1)
qc.barrier()
qc.cx(0, 1)
qc.h(0)
qc.barrier()
display(qc.draw('mpl'))

# %%
from qiskit.quantum_info import Statevector
sv = Statevector.from_instruction(qc)
sv.draw('latex')
# Out:
# $$0.4589782436 |000\rangle-0.4589782436 |001\rangle+0.1983405452 |010\rangle+0.1983405452 |011\rangle-0.1983405452 |100\rangle-0.1983405452 |101\rangle-0.4589782436 |110\rangle+0.4589782436 |111\rangle$$

# %%
result, state = sv.measure([0, 1])
print(f"Measured: {result}\nState after measurement:")
display(state.draw("latex"))
# Out:
# Measured: 11
# State after measurement:
# $$0.3966810904 |011\rangle+0.9179564873 |111\rangle$$

# %% [markdown]
# The snake equation with misty states.

# %%
a = QuantumCircuit(2)
a.x(0)
a.x(1)
a.barrier()
a.h(1)
a.cx(1, 0)
a.barrier()
display(a.draw('mpl'))

# %%
from qiskit.quantum_info import Statevector
sv = Statevector.from_instruction(a)
sv.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |01\rangle- \frac{\sqrt{2}}{2} |10\rangle$$
