# %%
# !pip install qiskit pylatexenc

# %%
import qiskit

# %%
from qiskit import *

# %%
circuit = QuantumCircuit(1, 1)
circuit.h(0)
circuit.s(0)
circuit.barrier()
circuit.draw(output='mpl')

# %%
from qiskit.quantum_info import Statevector
sv = Statevector.from_instruction(circuit)
sv.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2} i}{2} |1\rangle$$

# %%
# !pip install qiskit-aer

# %%
circuit.measure(range(1), range(1))

from qiskit_aer import AerSimulator
aersim = AerSimulator()
circuit = transpile(circuit, aersim)

# %%
circuit.draw(output='mpl')

# %%
result = aersim.run(circuit).result()
counts = result.get_counts(circuit)
print(result.get_counts(circuit))
# Out:
# {'1': 517, '0': 507}

# %%
from qiskit.visualization import plot_histogram
plot_histogram(counts, title='Measuring a state with complex probability amplitudes')

# %% [markdown]
# Task: do the same for the state $[(1-i) W , (1 + i) B ]$
